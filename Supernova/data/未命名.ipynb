# %% [markdown]
# # 文件内容

# %% [markdown]
# * id,x,y,judge
# - 2f52b895f03a214a3a077acd253066,177,152,newtarget
# - 1685708bdf8bf82f1ffce8705b109b,109,133,isstar
# - 2c55c0629a016be567c5fe76d3cf96,200,183,asteroid
# - bb4bc28935b60334153e7e8a5a06fd,6,526,isnova
# - 0099dd7961f5341f66d8cdcb89269b,268,181,known
# - b6fd78b5240058f5f6db837a16d48,117,107,noise
# - 2375a90b92dd4c71d1245b5332c134,246,78,ghost
# - fe2a17b1827a9eea1b5f2610aa7026,165,201,pity
# - 796ac41ed58be966f253b59a83419f,218,256,pity

# %% [markdown]
# ## 字段说明
# id 图片id，每个id对应一组图片（三张） x 标注中心点的横坐标 y 标注中心点的纵坐标 judge 高级用户对此标注的判定

# %% [markdown]
# ## 文件说明
# 图片以id前两位作为目录名分散在相应目录中，每组图片为三张Gray颜色空间图片，其中“_a”后缀为新图和历史图的差值图（减法图），“_b”后缀为新图，“_c”后缀为历史图，例如：
# - id：d52f52b895f03a214a3a077acd253066
# - 差值图：d5/d52f52b895f03a214a3a077acd253066_a.jpg
# - 新图：d5/d52f52b895f03a214a3a077acd253066_b.jpg
# - 历史图：d5/d52f52b895f03a214a3a077acd253066_c.jpg

# %% [markdown]
# ## 坐标和判定说明
# 每组图片中包含且仅包含一组坐标，近似为可疑目标的中心点。
# 判定共有8种取值，其中5种为被认可的星体，3种为标注点非星体。但list中不一定包含所有的判定，各种判定意义如下：
# ![image.png](attachment:image.png)
# 对于星体的具体种类，仅凭不同时间的两张图片对比不足以辨识，通常需要更多的资料来确认，所以本次区域赛中，我们仅检测定位疑似星体，即上述的五种情况。
# ![image.png](attachment:image.png)
# 以上三种情况标注位置在视觉上与星体的表现比较相似，但是并非星体。这部分数据供参赛选手参考，以更准确的检测星体。
#
# 每组图片除标注坐标外，不保证图片其他位置中是否存在某种情况。
